# %%
#!git clone https://github.com/gmargoth/bch_imae.git
#!git pull https://github.com/gmargoth/bch_imae.git

from bch_imae.bch_imae_download import login_SISEE,downaload_IMAE_query
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
username = 'gabriela123'
password = 'gabriela123'
save_to = 'C:\\Users\\gabri\\Downloads\\Query\\'
session = login_SISEE(username, password, save_to)

global_only = False
downaload_IMAE_query(session, global_only)
session.quit()

# %%
import pandas as pd
if global_only: 
        f_type = "xls" 
else: f_type = 'xlsx'

file = save_to + 'IndiceMensualIMAE.' + f_type
data = pd.read_excel(file)
display(data)
# Out:
#                                            Unnamed: 0  ... Unnamed: 285
# 0                           BANCO CENTRAL DE HONDURAS  ...          NaN
# 1               ÍNDICE MENSUAL DE ACTIVIDAD ECONÓMICA  ...          NaN
# 2                      SERIE MENSUAL A AGOSTO DE 2023  ...          NaN
# 3                                BASE FIJA (2000=100)  ...          NaN
# 4                                                 NaN  ...          NaN
# 5                                              CÓDIGO  ...       INDICE
# 6                                                 NaN  ...         2023
# 7                                                 NaN  ...       AGOSTO
# 8                                                   A  ...     178.6177
# 9                                                A.01  ...     156.1142
# 10                                               A.02  ...     102.8449
# 11                                               A.03  ...     172.3833
# ...

# %%
import os
file_path = file  # Replace with the path to the file you want to delete

if os.path.exists(file_path):
    os.remove(file_path)
    print(f"File {file_path} has been deleted.")
else:
    print(f"File {file_path} does not exist.")
# Out:
# File C:\Users\gabri\Downloads\Query\IndiceMensualIMAE.xlsx has been deleted.
